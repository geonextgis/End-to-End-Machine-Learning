# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
wheat_path = r"D:\GIS Project\Research Projects\Crop Classification 2\Dataset\Maize_Example.csv"
df = pd.read_csv(wheat_path, parse_dates=["system:time_start"])
df.head()
# Out:
#   system:time_start  GCVI  Fitted
# 0        2018-02-09   NaN     NaN
# 1        2018-02-12   NaN     NaN
# 2        2018-02-12   NaN     NaN
# 3        2018-02-14   NaN     NaN
# 4        2018-02-14   NaN     NaN

# %%
df2 = df.dropna()
df2.head()
# Out:
#    system:time_start   GCVI  Fitted
# 19        2018-03-31  0.693   0.829
# 21        2018-04-15  0.813   0.826
# 22        2018-04-15  0.839   0.793
# 23        2018-04-18  0.819   0.839
# 24        2018-04-18  0.822   0.812

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 19 to 116
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   system:time_start  80 non-null     datetime64[ns]
#  1   GCVI               80 non-null     float64
#  2   Fitted             80 non-null     float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 2.5 KB

# %%
df2.rename(columns={"system:time_start": "Date"}, inplace=True)
# Out:
# C:\Users\KRISH\AppData\Local\Temp\ipykernel_18452\1544140336.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns={"system:time_start": "Date"}, inplace=True)

# %%
df2
# Out:
#           Date   GCVI  Fitted
# 19  2018-03-31  0.693   0.829
# 21  2018-04-15  0.813   0.826
# 22  2018-04-15  0.839   0.793
# 23  2018-04-18  0.819   0.839
# 24  2018-04-18  0.822   0.812
# ..         ...    ...     ...
# 109 2018-11-16  2.354   2.240
# 112 2018-12-19  1.539   1.889
# 113 2018-12-19  1.600   1.898
# 115 2018-12-26  2.112   1.793
# 116 2018-12-26  2.023   1.830
#
# [80 rows x 3 columns]

# %%
fig, axs = plt.subplots(figsize=(20, 10))
sns.lineplot(x=df2["Date"], y=df2["GCVI"], marker="o", linewidth=1)
# Out:
# <Axes: xlabel='Date', ylabel='GCVI'>

# %%
sns.lineplot(
    data=df2,
    x="Date", y="GCVI",
    markers="o", dashes=False
)
# Out:
# <Axes: xlabel='Date', ylabel='GCVI'>

# %%
df2.to_csv("D:\GIS Project\Research Projects\Crop Classification 2\Dataset\Maize_Example_Processes.csv")
